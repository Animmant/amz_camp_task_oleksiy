# %% [markdown]
# # Setting Tasks

# %%
print('hellfo')
print("oh memoryview")

def print_seasons():
    seasons = ['spring', 'gae', 'autumn', 'winter']
    print("The seasons{} are:{}".format(seasons, seasons[0]))
# Out:
# hellfo
# oh memoryview

# %% [markdown]
# # Section 2
